# %% [markdown]
# # Climate
#
# IN THE SPACE BELOW, WRITE OUT IN FULL AND THEN SIGN THE HONOR PLEDGE:
#
# “I pledge my honor that I have not violated the honor code during this examination.”
#
# **PRINT NAME**:
#
# If a fellow student has contributed significantly to this work, please acknowledge them here:
#
# **Peer(s)**:
#
# *Contribution:*
#
#
# By uploading this assignment through Canvas, I sign off on the document below electronically.
#
# ----

# %% [markdown]
# ## Objectives
#
#
# **LOOK AT**https://uhlibraries.pressbooks.pub/historicalgeologylab/chapter/paleoclimate/
#
# - Describe the pattern of ocean δ18O variations over the past 2 million years, using data from
# benthic foraminifera.
# - Use this data to infer the pattern of ice-volume changes and identify glacial and inter-glacial
# periods.
# - Compare the benthic foraminifera results to CO2 record of ancient atmosphere trapped in
# bubbles in the Vostok, Antarctica ice core.

# %% [markdown]
# ## Review
# The concentration of <sup>18</sup>O in water and
# sediment is represented as $\delta$<sup>18</sup>O values with
# units of per mil (parts per thousand, or ‰).
# Average ocean water is assigned a value of
# 0‰, and is the standard against which
# variations in <sup>18</sup>O/<sup>16</sup>O are measured and
# reported. The process of fractionation, the
# preferential removal of one isotope over
# another during a phase change, results from
# the mass difference of water molecules
# containing <sup>18</sup>O (a.k.a., “heavy water”) and of
# water molecules containing <sup>16</sup>O (“light water”)
# in the Earth climate system.

# %% [markdown]
# <img src = "Images/isotopes_18O.png" width = "50%" >

# %% [markdown]
# **Question 1** Will ocean water be isotopically light or heavy during a glacial period, compared to during an interglacial period? Explain why.

# %% [markdown]
# ## $\delta$<sup>18</sup>O data and climate change from benthic forams
#
# A series of programs funded by the U.S. National Science Foundation and 22 international partners
# has used the scientific drill ship JOIDES Resolution (Joint Oceanographic Institute for Deep Earth
# Sampling) to drill into the ocean floor, both into unconsolidated sediment and into the ocean crust
# below the sediment:
# - 1968-1984: Deep Sea Drilling Project (DSDP)
# - 1985-2003: Ocean Drilling Project (ODP)
# - 2004-2012: Integrated Ocean Drilling Program (IODP)
# - 2013 and ongoing: International Ocean Discovery Program (IODP).

# %% [markdown]
# **Question 2** Describe the IODP expedition the Resolution is currently involved in and tell where the ship is
# right now! See current expedition information at https://iodp.tamu.edu/scienceops/sitesumm.html
#
#
# Here, you will analyze $\delta$<sup>18</sup>O data measured in foraminifera. “Forams” are shelled microorganisms
# found in aquatic environments. There are both planktonic (floating in the water column) and benthic
# (bottom dwelling) varieties. Foram shells are made up of calcium carbonate (CaCO<sub>3</sub>) and when the
# organisms die, their shells get buried and preserved in sediment. The chemical make-up of the shells
# reflects the water chemistry at the time of shell formation. For this problem set, we focus on the
# benthic forams which better reflect bulk ocean chemistry as opposed to planktonic forams which
# better reflect surface water temperature.

# %% [markdown]
# For each sample, you are given the depth in the core, the age of the
# sample, and the δ18O of forams at that spot.
# Note: Excel is a fine tool to use for this exercise, but feel free to paste the data into any other
# graphing program you like to produce the graphs.
#
#
# **Question 3** How long is ODP core 677? How much geologic time is represented by the entire core?
#
# **Question 4** For the upper two meters of the core:
#
# **Question 4.1** Calculate the sedimentation rate in mm/yr for this time period.
#
# **Question 4.2** Approximately how many years would be represented by 10 cm of sediment?

# %% [markdown]
# **Question 4** Create an X-Y plot of $\delta$<sup>18</sup>O (on the y-axis) as a function of age (on the x-axis) for the past 2 million years using the following guidelines
# - Plot the data connected with straight lines, no point markers.
# - An appropriate title
# - The name for the x-axis should be "Age (yr)", and the name for the y-axis should be "$\delta$<sup>18</sup>O (‰)".
# - For the Y-axis, use a minimum value of 3.0 and a maximum value of 6.0.
# - For the X-axis, use a maximum value of 2 million years, and display the values on the
# Y-axis so that modern times is to the right, and age increases to the left.
#
# **Question 5** Make a second graph that is only for the past 500,000 years to focus in on that time interval.

# %% [markdown]
# https://www.ncei.noaa.gov/access/paleo-search/study/5847
#
# Lisiecki, L.E. and M.E. Raymo. 2005. A Pliocene-Pleistocene stack of 57 globally distributed benthic D18O records. Paleoceanography, 20, PA1003. doi: 10.1029/2004PA001071

# %%
import pandas as pd
benthic2005d18O = pd.read_excel('Files/lisiecki2005.xls', sheet_name='benthic_d18O')

# %%
benthic2005d18O
# Out:
#       Time_(ka)  Benthic_d18O_(per_mil)  Standard_error_(per_mil)
# 0             0                    3.23                      0.03
# 1             1                    3.23                      0.04
# 2             2                    3.18                      0.03
# 3             3                    3.29                      0.03
# 4             4                    3.30                      0.03
# ...         ...                     ...                       ...
# 1810       5300                    2.91                      0.06
# 1811       5305                    2.79                      0.04
# 1812       5310                    2.79                      0.09
# 1813       5315                    2.84                      0.07
# 1814       5320                    2.91                      0.09
#
# [1815 rows x 3 columns]

# %% [markdown]
# https://www.ncei.noaa.gov/access/paleo-search/study/17975
#
# Bereiter, B., S. Eggleston, J. Schmitt, C. Nehrbass-Ahles, T. F. Stocker, H. Fischer, S. Kipfstuhl, J. Chappellaz. 2015. Revision of the EPICA Dome C CO2 record from 800 to 600 kyr before present. Geophysical Research Letters, 42(2), 542-549. doi: 10.1002/2014GL061957

# %%
import pandas as pd
antarctica2015co2 = pd.read_excel('Files/antarctica2015co2.xls', sheet_name='CO2 Composite', header=14)

# %%
antarctica2015co2
# Out:
#       Gasage (yr BP)  CO2 (ppmv)  sigma mean CO2 (ppmv)
# 0         -51.030000  368.022488               0.060442
# 1         -48.000000  361.780737               0.370000
# 2         -46.279272  359.647793               0.098000
# 3         -44.405642  357.106740               0.159923
# 4         -43.080000  353.946685               0.043007
# ...              ...         ...                    ...
# 1896   803925.284376  202.921723               2.064488
# 1897   804009.870607  207.498645               0.915083
# 1898   804522.674630  204.861938               1.642851
# 1899   805132.442334  202.226839               0.689587
# 1900   805668.868405  207.285440               2.202808
#
# [1901 rows x 3 columns]

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Scatter(x=antarctica2015co2['Gasage (yr BP)'], y=antarctica2015co2['CO2 (ppmv)'], mode='markers'))
fig['layout']['xaxis']['autorange'] = "reversed"
fig.show()

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Scatter(x=benthic2005d18O['Time_(ka)']*1000, y=benthic2005d18O['Benthic_d18O_(per_mil)'], mode='markers'))
fig['layout']['xaxis']['autorange'] = "reversed"
fig.show()

# %% [markdown]
# ### Comparison of climate records from Antarctica (Q4) and the equatorial Pacific (Q3)
#
# **Question** Compare the CO2 data from the Vostok ice core, with the δ18 O data from the equatorial Pacific.
# Do they tell a consistent picture of global climate over the last 414,000 years? Explain in a brief,
# well-written paragraph or two, referring appropriately to the data sets and graphs.

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=benthic2005d18O['Time_(ka)']*1000, y=benthic2005d18O['Benthic_d18O_(per_mil)'],
                    mode='lines+markers',
                    name='d18O'))
fig.add_trace(go.Scatter(x=antarctica2015co2['Gasage (yr BP)'], y=antarctica2015co2['CO2 (ppmv)'],
                    mode='lines+markers',
                    name='CO2',yaxis="y2"))

# Create axis objects
fig.update_layout(
    xaxis=dict(
        domain=[0., 1.]
    ),
    yaxis=dict(
        title="yaxis title",
        titlefont=dict(
            color="#1f77b4"
        ),
        tickfont=dict(
            color="#1f77b4"
        )
    ),
    yaxis2=dict(
        title="yaxis2 title",
        titlefont=dict(
            color="#ff7f0e"
        ),
        tickfont=dict(
            color="#ff7f0e"
        ),
        anchor="x",
        overlaying="y",
        side="right",
        position=0.15
    )
)


fig['layout']['xaxis']['autorange'] = "reversed"
fig.show()

# %% [markdown]
# **Question**  Modern Measurements: What is the CO<sub>2</sub> content of Earth’s atmosphere today. Plot the values from Muana Loa from 1958 to 2022
#     There are also data for CH4, N20 and SF6 as well

# %% [markdown]
# **Question**  Revisit your response to item 3.12. Do you think we are due for the onset of the next ice age?
# Explain why or why not.

# %% [markdown]
# http://climatemodels.uchicago.edu/geocarb/geocarb.doc.html
